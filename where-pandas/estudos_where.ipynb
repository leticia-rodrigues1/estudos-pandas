# %%
import pandas as pd
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    str
#  3   smoker      244 non-null    str
#  4   day         244 non-null    str
#  5   time        244 non-null    str
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 13.5 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(exclude="number")
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
for coluna in df.select_dtypes(include="object"):
    print(f"{coluna}:{df[coluna].unique()}")
# Out:
# sex:<StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
# smoker:<StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# day:<StringArray>
# ['Sun', 'Sat', 'Thur', 'Fri']
# Length: 4, dtype: str
# time:<StringArray>
# ['Dinner', 'Lunch']
# Length: 2, dtype: str
# C:\Users\User\AppData\Local\Temp\ipykernel_11112\88187916.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for coluna in df.select_dtypes(include="object"):

# %%
df["tip"].hist( )
# Out:
# <Axes: >

# %%
df.boxplot("tip", vert=False, grid=False)
# Out:
# <Axes: >

# %% [markdown]
# ##Método WHERE

# %%
df["tip"].mean()
# Out:
# np.float64(2.99827868852459)

# %%
df.where(df["tip"] > df["tip"].mean())
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0           NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 1           NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240         NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 241         NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 242         NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [244 rows x 7 columns]

# %%
df.where(df["tip"] > df["tip"].mean(), 0)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0          0.00  0.00       0      0     0       0     0
# 1          0.00  0.00       0      0     0       0     0
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240        0.00  0.00       0      0     0       0     0
# 241        0.00  0.00       0      0     0       0     0
# 242        0.00  0.00       0      0     0       0     0
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.where(df["tip"] > df["tip"].mean(), "nulo")
# Out:
#     total_bill   tip     sex smoker   day    time  size
# 0         nulo  nulo    nulo   nulo  nulo    nulo  nulo
# 1         nulo  nulo    nulo   nulo  nulo    nulo  nulo
# 2        21.01   3.5    Male     No   Sun  Dinner     3
# 3        23.68  3.31    Male     No   Sun  Dinner     2
# 4        24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...   ...     ...    ...   ...     ...   ...
# 239      29.03  5.92    Male     No   Sat  Dinner     3
# 240       nulo  nulo    nulo   nulo  nulo    nulo  nulo
# 241       nulo  nulo    nulo   nulo  nulo    nulo  nulo
# 242       nulo  nulo    nulo   nulo  nulo    nulo  nulo
# 243      18.78   3.0  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.where((df["tip"] > df["tip"].mean()) & (df["day"].isin(["Sat", "Sun"])))
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0           NaN   NaN     NaN    NaN  NaN     NaN   NaN
# 1           NaN   NaN     NaN    NaN  NaN     NaN   NaN
# 2         21.01  3.50    Male     No  Sun  Dinner   3.0
# 3         23.68  3.31    Male     No  Sun  Dinner   2.0
# 4         24.59  3.61  Female     No  Sun  Dinner   4.0
# ..          ...   ...     ...    ...  ...     ...   ...
# 239       29.03  5.92    Male     No  Sat  Dinner   3.0
# 240         NaN   NaN     NaN    NaN  NaN     NaN   NaN
# 241         NaN   NaN     NaN    NaN  NaN     NaN   NaN
# 242         NaN   NaN     NaN    NaN  NaN     NaN   NaN
# 243         NaN   NaN     NaN    NaN  NaN     NaN   NaN
#
# [244 rows x 7 columns]

# %% [markdown]
# ##Como tirar o NaN

# %%
df_weekend = df.where((df["tip"] > df["tip"].mean()) & (df["day"].isin(["Sat", "Sun"]))).dropna()
df_weekend
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 2         21.01  3.50    Male     No  Sun  Dinner   3.0
# 3         23.68  3.31    Male     No  Sun  Dinner   2.0
# 4         24.59  3.61  Female     No  Sun  Dinner   4.0
# 5         25.29  4.71    Male     No  Sun  Dinner   4.0
# 7         26.88  3.12    Male     No  Sun  Dinner   4.0
# ..          ...   ...     ...    ...  ...     ...   ...
# 231       15.69  3.00    Male    Yes  Sat  Dinner   3.0
# 232       11.61  3.39    Male     No  Sat  Dinner   2.0
# 234       15.53  3.00    Male    Yes  Sat  Dinner   2.0
# 238       35.83  4.67  Female     No  Sat  Dinner   3.0
# 239       29.03  5.92    Male     No  Sat  Dinner   3.0
#
# [89 rows x 7 columns]

# %%
df_weekend = (
    df.where((df["tip"] > df["tip"].mean()) & (df["day"].isin(["Sat", "Sun"])))
    .dropna()
    .reset_index(drop=True)
)

df_weekend
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        21.01  3.50    Male     No  Sun  Dinner   3.0
# 1        23.68  3.31    Male     No  Sun  Dinner   2.0
# 2        24.59  3.61  Female     No  Sun  Dinner   4.0
# 3        25.29  4.71    Male     No  Sun  Dinner   4.0
# 4        26.88  3.12    Male     No  Sun  Dinner   4.0
# ..         ...   ...     ...    ...  ...     ...   ...
# 84       15.69  3.00    Male    Yes  Sat  Dinner   3.0
# 85       11.61  3.39    Male     No  Sat  Dinner   2.0
# 86       15.53  3.00    Male    Yes  Sat  Dinner   2.0
# 87       35.83  4.67  Female     No  Sat  Dinner   3.0
# 88       29.03  5.92    Male     No  Sat  Dinner   3.0
#
# [89 rows x 7 columns]

# %% [markdown]
# ##FUNÇÃO WHERE NO NUMPY

# %%
import numpy as np

np.where(df["tip"]> df["tip"].mean())
# Out:
# (array([  2,   3,   4,   5,   7,   9,  11,  13,  14,  15,  17,  18,  19,
#          20,  23,  24,  28,  29,  32,  34,  35,  37,  39,  42,  44,  45,
#          46,  47,  49,  52,  54,  55,  56,  59,  60,  63,  65,  71,  72,
#          73,  76,  77,  78,  80,  81,  83,  85,  87,  88,  89,  90,  91,
#          93,  94,  95,  96,  98, 101, 103, 104, 106, 107, 108, 109, 110,
#         112, 114, 115, 116, 125, 134, 140, 141, 142, 143, 155, 156, 157,
#         160, 164, 165, 167, 170, 171, 172, 173, 174, 175, 178, 179, 180,
#         181, 182, 183, 184, 185, 186, 188, 189, 191, 194, 197, 200, 204,
#         205, 206, 207, 211, 212, 214, 216, 219, 221, 223, 227, 231, 232,
#         234, 238, 239, 243]),)

# %%
np.where(df["tip"]> df["tip"].mean(), "Sim", "Não")
# Out:
# array(['Não', 'Não', 'Sim', 'Sim', 'Sim', 'Sim', 'Não', 'Sim', 'Não',
#        'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Sim', 'Sim', 'Não', 'Sim',
#        'Sim', 'Sim', 'Sim', 'Não', 'Não', 'Sim', 'Sim', 'Não', 'Não',
#        'Não', 'Sim', 'Sim', 'Não', 'Não', 'Sim', 'Não', 'Sim', 'Sim',
#        'Não', 'Sim', 'Não', 'Sim', 'Não', 'Não', 'Sim', 'Não', 'Sim',
#        'Sim', 'Sim', 'Sim', 'Não', 'Sim', 'Não', 'Não', 'Sim', 'Não',
#        'Sim', 'Sim', 'Sim', 'Não', 'Não', 'Sim', 'Sim', 'Não', 'Não',
#        'Sim', 'Não', 'Sim', 'Não', 'Não', 'Não', 'Não', 'Não', 'Sim',
#        'Sim', 'Sim', 'Não', 'Não', 'Sim', 'Sim', 'Sim', 'Não', 'Sim',
#        'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Sim', 'Sim',
#        'Sim', 'Sim', 'Não', 'Sim', 'Sim', 'Sim', 'Sim', 'Não', 'Sim',
#        'Não', 'Não', 'Sim', 'Não', 'Sim', 'Sim', 'Não', 'Sim', 'Sim',
#        'Sim', 'Sim', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Sim', 'Sim',
#        'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Sim',
#        'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Sim',
#        'Não', 'Não', 'Não', 'Não', 'Não', 'Sim', 'Sim', 'Sim', 'Sim',
#        'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Não', 'Não',
#        'Não', 'Não', 'Sim', 'Sim', 'Sim', 'Não', 'Não', 'Sim', 'Não',
#        'Não', 'Não', 'Sim', 'Sim', 'Não', 'Sim', 'Não', 'Não', 'Sim',
#        'Sim', 'Sim', 'Sim', 'Sim', 'Sim', 'Não', 'Não', 'Sim', 'Sim',
#        'Sim', 'Sim', 'Sim', 'Sim', 'Sim', 'Sim', 'Sim', 'Não', 'Sim',
#        'Sim', 'Não', 'Sim', 'Não', 'Não', 'Sim', 'Não', 'Não', 'Sim',
#        'Não', 'Não', 'Sim', 'Não', 'Não', 'Não', 'Sim', 'Sim', 'Sim',
#        'Sim', 'Não', 'Não', 'Não', 'Sim', 'Sim', 'Não', 'Sim', 'Não',
#        'Sim', 'Não', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não',
#        'Não', 'Não', 'Sim', 'Não', 'Não', 'Não', 'Sim', 'Sim', 'Não',
#        'Sim', 'Não', 'Não', 'Não', 'Sim', 'Sim', 'Não', 'Não', 'Não',
#        'Sim'], dtype='<U3')

# %%
df["acima_da_media"]= np.where(df["tip"]> df["tip"].mean(), "Sim", "Não")

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size acima_da_media
# 0       16.99  1.01  Female     No  Sun  Dinner     2            Não
# 1       10.34  1.66    Male     No  Sun  Dinner     3            Não
# 2       21.01  3.50    Male     No  Sun  Dinner     3            Sim
# 3       23.68  3.31    Male     No  Sun  Dinner     2            Sim
# 4       24.59  3.61  Female     No  Sun  Dinner     4            Sim

# %%
df["final_de_semana"] = np.where(
    df["day"].isin(["Sat", "Sun"]),
    "Sim",
    "Não"
)

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size acima_da_media  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3            Sim
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2            Não
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2            Não
# 242       17.82  1.75    Male     No   Sat  Dinner     2            Não
# 243       18.78  3.00  Female     No  Thur  Dinner     2            Sim
#
#     final_de_semana
# 239             Sim
# 240             Sim
# 241             Sim
# 242             Sim
# 243             Não

# %% [markdown]
# ##Outlier = valor fora do padrão / valor muito diferente dos demais.
#
# ##Outlier = dado "esquisito" que foge muito do comportamento normal.
#
# ##Outlier não é uma função do Pandas, e sim um conceito de análise de dados.

# %%
def outliers(dataframe, coluna, bigode=1.5, nova_coluna="outlier"):
    q1 = dataframe[coluna].quantile(0.25)
    q3 = dataframe[coluna].quantile(0.75)
    iqr = q3 - q1

    limite_inferior = q1 - bigode * iqr
    limite_superior = q3 + bigode * iqr

    condicoes = (
        (dataframe[coluna] < limite_inferior) |
        (dataframe[coluna] > limite_superior)
    )

    dataframe[nova_coluna] = np.where(condicoes, "Sim", "Não")

    return dataframe

# %%
outliers(df,"tip")
# Out:
#      total_bill   tip     sex smoker   day    time  size acima_da_media  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2            Não
# 1         10.34  1.66    Male     No   Sun  Dinner     3            Não
# 2         21.01  3.50    Male     No   Sun  Dinner     3            Sim
# 3         23.68  3.31    Male     No   Sun  Dinner     2            Sim
# 4         24.59  3.61  Female     No   Sun  Dinner     4            Sim
# ..          ...   ...     ...    ...   ...     ...   ...            ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3            Sim
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2            Não
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2            Não
# 242       17.82  1.75    Male     No   Sat  Dinner     2            Não
# 243       18.78  3.00  Female     No  Thur  Dinner     2            Sim
#
#     final_de_semana outlier
# 0               Sim     Não
# 1               Sim     Não
# 2               Sim     Não
# 3               Sim     Não
# 4               Sim     Não
# ..              ...     ...
# 239             Sim     Sim
# 240             Sim     Não
# 241             Sim     Não
# 242             Sim     Não
# 243             Não     Não
#
# [244 rows x 10 columns]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size acima_da_media  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2            Não
# 1         10.34  1.66    Male     No   Sun  Dinner     3            Não
# 2         21.01  3.50    Male     No   Sun  Dinner     3            Sim
# 3         23.68  3.31    Male     No   Sun  Dinner     2            Sim
# 4         24.59  3.61  Female     No   Sun  Dinner     4            Sim
# ..          ...   ...     ...    ...   ...     ...   ...            ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3            Sim
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2            Não
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2            Não
# 242       17.82  1.75    Male     No   Sat  Dinner     2            Não
# 243       18.78  3.00  Female     No  Thur  Dinner     2            Sim
#
#     final_de_semana outlier
# 0               Sim     Não
# 1               Sim     Não
# 2               Sim     Não
# 3               Sim     Não
# 4               Sim     Não
# ..              ...     ...
# 239             Sim     Sim
# 240             Sim     Não
# 241             Sim     Não
# 242             Sim     Não
# 243             Não     Não
#
# [244 rows x 10 columns]

# %%
df["outlier"].value_counts()
# Out:
# outlier
# Não    235
# Sim      9
# Name: count, dtype: int64
