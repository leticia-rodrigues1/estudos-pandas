# %%
# requests.get() → baixou a página
# pagina.text → pegou o HTML
# StringIO() → transformou em "arquivo"
# pd.read_html() → leu as tabelas

import pandas as pd
import requests
from io import StringIO

URL = "https://pt.wikipedia.org/wiki/Lista_das_maiores_empresas_do_Brasil"

headers = {
    "User-Agent": "Mozilla/5.0"
}

pagina = requests.get(URL, headers=headers)

tabelas = pd.read_html(StringIO(pagina.text))

tabelas
# Out:
# [     #  Forbes Global 2000                Nome  Receita (em bilhões de US$)  \
#  0    1                  58           Petrobras                        12417
#  1    2                  98       Itaú Unibanco                         5317
#  2    3                 139                Vale                         4143
#  3    4                 171     Banco do Brasil                         5398
#  4    5                 173            Bradesco                         5626
#  5    6                 372         BTG Pactual                         1549
#  6    7                 563                 JBS                         7258
#  7    8                 774              Suzano                          996
#  8    9                 928          Eletrobras                          679
#  9   10                 980              Gerdau                          157
#  10  11                1015             Marfrig                         2529
# ...

# %%
# len é para ver o comprimento da tabela 
# aqui ele trouxe uma resposta que encontrou 7 tabelas 
len(tabelas)
# Out:
# 7

# %%
# aqui a gente pegou a primeira tabela queé a zero porque no Python começa a contagem do zero
tabelas[0]
# Out:
#      #  Forbes Global 2000                Nome  Receita (em bilhões de US$)  \
# 0    1                  58           Petrobras                        12417
# 1    2                  98       Itaú Unibanco                         5317
# 2    3                 139                Vale                         4143
# 3    4                 171     Banco do Brasil                         5398
# 4    5                 173            Bradesco                         5626
# 5    6                 372         BTG Pactual                         1549
# 6    7                 563                 JBS                         7258
# 7    8                 774              Suzano                          996
# 8    9                 928          Eletrobras                          679
# 9   10                 980              Gerdau                          157
# 10  11                1015             Marfrig                         2529
# ...

# %%
df_forbes_2000 = tabelas[0]

df_forbes_2000 = df_forbes_2000.drop(columns=["#"])

df_forbes_2000
# Out:
#     Forbes Global 2000                Nome  Receita (em bilhões de US$)  \
# 0                   58           Petrobras                        12417
# 1                   98       Itaú Unibanco                         5317
# 2                  139                Vale                         4143
# 3                  171     Banco do Brasil                         5398
# 4                  173            Bradesco                         5626
# 5                  372         BTG Pactual                         1549
# 6                  563                 JBS                         7258
# 7                  774              Suzano                          996
# 8                  928          Eletrobras                          679
# 9                  980              Gerdau                          157
# 10                1015             Marfrig                         2529
# 11                1026              Itaúsa                          164
# ...

# %%
# TRABALHANDO COM OS DADOS 

df_forbes_2000.columns = df_forbes_2000.columns.str.replace(r"(em bilhões de US$)", "")
df_forbes_2000.columns
# Out:
# Index(['Forbes Global 2000', 'Nome', 'Receita ', 'Lucro ', 'Ativos ', 'Valor ',
#        'Setor'],
#       dtype='str')

# %%
df_forbes_2000
# Out:
#     Forbes Global 2000                Nome  Receita   Lucro   Ativos   Valor   \
# 0                   58           Petrobras     12417    3647     1849    6303
# 1                   98       Itaú Unibanco      5317     575     4414    5128
# 2                  139                Vale      4143    1598     8772    6172
# 3                  171     Banco do Brasil      5398     576    38027    2485
# 4                  173            Bradesco      5626     349    35745     316
# 5                  372         BTG Pactual      1549     152     8535    5077
# 6                  563                 JBS      7258     299     3942     816
# 7                  774              Suzano       996     355      267    1095
# 8                  928          Eletrobras       679      70     5118    1728
# 9                  980              Gerdau       157     227     1494     873
# 10                1015             Marfrig      2529      80     2578     894
# ...
